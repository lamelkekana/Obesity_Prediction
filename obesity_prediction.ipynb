# %% [markdown]
# <h1 style="text-align:center; font-weight:bold; border: 2px solid black; padding: 10px; border-radius: 10px; background-color: #f2f2f2;">
#     <span style="color: #66b3ff;">Know Your Health</span>: Predict Your Obesity Risk with Ease
# </h1>

# %% [markdown]
# <center>
#   <div style="border: 4px solid #66b3ff; padding: 10px; display: inline-block; background-color: #fff; border-radius: 12px; box-shadow: 0 8px 16px rgba(0, 0, 0, 0.2); transform: scale(1); transition: transform 0.3s ease;">
#     <img src="https://cdn.pixabay.com/photo/2022/03/07/07/20/weighing-scale-7053082_1280.jpg" width="600" style="border-radius: 8px;"/>
#   </div>
# </center>

# %% [markdown]
# <style>
#     /* Table of contents container */
#     .toc {
#         background-color: #3e3e3e; /* Medium grey background */
#         color: #fff;
#         padding: 12px 18px;
#         margin: 20px 0;
#         border-radius: 12px;
#         box-shadow: 0 6px 12px rgba(0, 0, 0, 0.2);
#         width: 400px;
#         font-size: 1em;
#         font-family: 'Arial', sans-serif;
#         border: 3px solid #5a5a5a; /* Darker grey border */
#     }
#
#     /* Header */
#     .toc h1 {
#         text-align: center;
#         font-size: 1.8em;
#         color: #f8f9fa;
#         text-transform: uppercase;
#         margin-bottom: 12px;
#         font-family: 'Verdana', sans-serif;
#         letter-spacing: 1px;
#         text-shadow: 2px 2px 4px rgba(0, 0, 0, 0.2);
#     }
#
#     /* Unordered list styling */
#     .toc ul {
#         list-style-type: none;
#         padding-left: 0;
#         margin: 0;
#     }
#
#     /* List item styling */
#     .toc li {
#         margin: 6px 0;
#         font-size: 1.1em;
#         text-shadow: 1px 1px 2px rgba(0, 0, 0, 0.2);
#     }
#
#     /* Link styling */
#     .toc a {
#         color: #f1f1f1;
#         text-decoration: none;
#         padding: 6px 10px;
#         border-radius: 6px;
#         display: block;
#         background-color: #545454; /* Grey tone */
#         transition: background-color 0.3s, color 0.3s;
#     }
#
#     /* Hover effect for links */
#     .toc a:hover {
#         background-color: #6b6b6b; /* Lighter grey on hover */
#         color: white;
#         box-shadow: 0 0 8px rgba(255, 255, 255, 0.3);
#     }
#
#     /* Active state effect for links */
#     .toc a:active {
#         background-color: #444; /* Darker active state */
#         color: white;
#         box-shadow: 0 0 6px rgba(255, 255, 255, 0.5);
#     }
#
#     /* Nested list styling (subsections) */
#     .toc .sublist {
#         margin-left: 10px;
#         list-style-type: circle;
#         padding-left: 8px;
#     }
#
#     .toc .sublist a {
#         background-color: #666; /* Slightly lighter grey */
#         padding: 5px 10px;
#         border-radius: 6px;
#         transition: background-color 0.3s, color 0.3s;
#     }
#
#     .toc .sublist a:hover {
#         background-color: #444; /* Darker grey hover */
#         color: white;
#         box-shadow: 0 0 6px rgba(255, 255, 255, 0.3);
#     }
#
# </style>
#
# <div class="toc">
#     <h1>Table of Contents</h1>
#     <ul>
#         <li><a href="#1-Introduction">1. Introduction</a>
#             <ul class="sublist">
#                 <li><a href="#1-1-Problem-Statement">1.1. Problem Statement</a></li>
#                 <li><a href="#1-2-Objectives">1.2. Objectives</a></li>
#             </ul>
#         </li>
#         <li><a href="#2-Importing-Packages">2. Importing Packages</a></li>
#         <li><a href="#3-Data-loading">3. Data Loading</a></li>
#         <li><a href="#4-Data-Cleaning">4. Data Cleaning</a></li>
#         <li><a href="#5-Data-Preprocessing">5. Data Preprocessing</a></li>
#         <li><a href="#6-Exploratory-Data-Analysis-EDA">6. Exploratory Data Analysis (EDA)</a></li>
#         <li><a href="#7-Model-development">7. Model Development</a></li>
#         <li><a href="#8-Model-Evaluation">8. Model Evaluation</a></li>
#         <li><a href="#9-Model-Deployment">9. Model Deployment</a></li>
#         <li><a href="#10-Conclusion">10. Conclusion</a></li>
#         <li><a href="#11-Recommendations">11. Recommendations</a></li>
#         <li><a href="#12-References">12. References</a></li>
#     </ul>
# </div>

# %% [markdown]
# #
#
# <div style="text-align: center; border-top: 3px solid black; padding: 10px;">
#     <h2><strong>1. Introduction</strong></h2>
# </div>

# %% [markdown]
# <!DOCTYPE html>
# <html lang="en">
# <head>
#     <meta charset="UTF-8">
#     <meta name="viewport" content="width=device-width, initial-scale=1.0">
#     <style>
#         body { font-family: Arial, sans-serif; background: #f4f4f4; padding: 40px; }
#         .container { max-width: 800px; margin: 0 auto; background: white; padding: 20px; border-radius: 8px; box-shadow: 0 4px 8px rgba(0, 0, 0, 0.1); }
#         h2 { text-align: center; color: #333; }
#         p { line-height: 1.6; color: #555; }
#         .highlight { color: #66b3ff; font-weight: bold; } /* Lighter blue */
#     </style>
# </head>
# <body>
#     <div class="container">
#         <p>This project aims to develop a predictive model that assesses the risk of <span class="highlight">obesity</span> based on a range of health and lifestyle factors. By analyzing key attributes like <span class="highlight">age</span>, <span class="highlight">height</span>, <span class="highlight">weight</span>, <span class="highlight">family history</span>, <span class="highlight">physical activity</span>, <span class="highlight">eating habits</span>, and more, the model will provide an accurate prediction of <span class="highlight">obesity</span> status. The goal is to help individuals understand their <span class="highlight">risk factors</span> and make informed decisions to improve their health and well-being. Using data science techniques like <span class="highlight">classification</span> and <span class="highlight">machine learning</span>, the project explores the relationship between lifestyle factors and obesity risk to create a reliable prediction tool.</p>
#     </div>
# </body>
# </html>

# %% [markdown]
# <div style="text-align: center; border-top: 3px solid black; padding: 10px; width: 60%; margin: 0 auto;">
#     <h3><strong>1.1. Problem Statement</strong></h3>
# </div>

# %% [markdown]
# <!DOCTYPE html>
# <html lang="en">
# <head>
#     <meta charset="UTF-8">
#     <meta name="viewport" content="width=device-width, initial-scale=1.0">
#     <style>
#         body { font-family: Arial, sans-serif; background: #f4f4f4; padding: 40px; }
#         .container { max-width: 800px; margin: 0 auto; background: white; padding: 20px; border-radius: 8px; box-shadow: 0 4px 8px rgba(0, 0, 0, 0.1); }
#         h2 { text-align: center; color: #333; }
#         p { line-height: 1.6; color: #555; }
#         .highlight { color: #66b3ff; font-weight: bold; } /* Lighter blue */
#     </style>
# </head>
# <body>
#     <div class="container">
#         <p><span class="highlight">Obesity</span> is a growing global health concern, influenced by <span class="highlight">genetic</span>, <span class="highlight">dietary</span>, and <span class="highlight">lifestyle factors</span>. Early prediction of <span class="highlight">obesity risk</span> can help in designing preventive measures and promoting healthier lifestyles. This project aims to analyze various factors contributing to <span class="highlight">obesity</span> and build <span class="highlight">machine learning models</span> to predict <span class="highlight">obesity levels</span> based on individual characteristics and behaviors.</p>
#     </div>
# </body>
# </html>

# %% [markdown]
# <div style="text-align: center; border-top: 3px solid black; padding: 10px; width: 60%; margin: 0 auto;">
#     <h3><strong>1.2. Objectives</strong></h3>
# </div>

# %% [markdown]
# <!DOCTYPE html>
# <html lang="en">
# <head>
#     <meta charset="UTF-8">
#     <meta name="viewport" content="width=device-width, initial-scale=1.0">
#     <style>
#         body { font-family: Arial, sans-serif; background: #f4f4f4; padding: 40px; }
#         .container { max-width: 800px; margin: 0 auto; background: white; padding: 20px; border-radius: 8px; box-shadow: 0 4px 8px rgba(0, 0, 0, 0.1); }
#         h2 { text-align: center; color: #333; }
#         p { line-height: 1.6; color: #555; }
#         .highlight { color: #66b3ff; font-weight: bold; } /* Lighter blue */
#     </style>
# </head>
# <body>
#     <div class="container">
#         <ul>
#             <li><span class="highlight">Explore and preprocess data:</span> Clean, analyze, and visualize patterns.</li>
#             <li><span class="highlight">Identify key contributors:</span> Assess lifestyle, diet, and activity impacts.</li>
#             <li><span class="highlight">Develop predictive models:</span> Use <span class="highlight">ML</span> to classify obesity levels.</li>
#             <li><span class="highlight">Evaluate performance:</span> Measure accuracy, precision, and recall.</li>
#             <li><span class="highlight">Generate insights:</span> Provide findings for obesity prevention.</li>
#         </ul>
#     </div>
# </body>
# </html>

# %% [markdown]
# #
#
#
# <div style="text-align: center; border-top: 3px solid black; padding: 10px;">
#     <h2><strong>2.Data Dictionary</strong></h2>
# </div>

# %% [markdown]
# <!DOCTYPE html>
# <html lang="en">
# <head>
#     <meta charset="UTF-8">
#     <meta name="viewport" content="width=device-width, initial-scale=1.0">
#     <style>
#         body { font-family: Arial, sans-serif; background: #f4f4f4; padding: 40px; }
#         .container { max-width: 800px; margin: 0 auto; background: white; padding: 20px; border-radius: 8px; box-shadow: 0 4px 8px rgba(0, 0, 0, 0.1); }
#         h2 { text-align: center; color: #333; }
#         p { line-height: 1.6; color: #555; }
#         .highlight { color: #66b3ff; font-weight: bold; } /* Lighter blue */
#     </style>
# </head>
# <body>
#     <div class="container">
#         <ul>
#             <li><span class="highlight">Gender:</span> Gender</li>
#             <li><span class="highlight">Age:</span> Age</li>
#             <li><span class="highlight">Height:</span> in metres</li>
#             <li><span class="highlight">Weight:</span> in kgs</li>
#             <li><span class="highlight">family_history:</span> Has a family member suffered or suffers from overweight?</li>
#             <li><span class="highlight">FAVC:</span> Do you eat high caloric food frequently?</li>
#             <li><span class="highlight">FCVC:</span> Do you usually eat vegetables in your meals?</li>
#             <li><span class="highlight">NCP:</span> How many main meals do you have daily?</li>
#             <li><span class="highlight">CAEC:</span> Do you eat any food between meals?</li>
#             <li><span class="highlight">SMOKE:</span> Do you smoke?</li>
#             <li><span class="highlight">CH2O:</span> How much water do you drink daily?</li>
#             <li><span class="highlight">SCC:</span> Do you monitor the calories you eat daily?</li>
#             <li><span class="highlight">FAF:</span> How often do you have physical activity?</li>
#             <li><span class="highlight">TUE:</span> How much time do you use technological devices such as cell phone, videogames, television, computer, and others?</li>
#             <li><span class="highlight">CALC:</span> How often do you drink alcohol?</li>
#             <li><span class="highlight">MTRANS:</span> Which transportation do you usually use?</li>
#             <li><span class="highlight">Obesity_level (Target Column):</span> Obesity level</li>
#         </ul>
#     </div>
# </body>
# </html>

# %% [markdown]
# #
#
# <div style="text-align: center; border-top: 3px solid black; padding: 10px;">
#     <h2><strong>3.Importing Packages</strong></h2>
# </div>

# %%
# Basic Packages
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
import warnings
warnings.filterwarnings("ignore")

# Preprocessing Packages
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA

# Model Development Packages
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC
from xgboost import XGBClassifier
from sklearn.model_selection import GridSearchCV
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import RandomizedSearchCV
from sklearn.metrics import confusion_matrix, classification_report, accuracy_score, log_loss
from sklearn.metrics import roc_curve, auc
from sklearn.metrics import confusion_matrix
from sklearn.metrics import ConfusionMatrixDisplay

# %% [markdown]
# #
#
# <div style="text-align: center; border-top: 3px solid black; padding: 10px;">
#     <h2><strong>3.Data Loading and Inspecting</strong></h2>
# </div>

# %% [markdown]
# In this step, we begin by loading the dataset into the environment and performing an initial inspection to understand its structure and the nature of the data

# %%
# Load csv file into a DataFrame
df = pd.read_csv("Obesity prediction.csv")

# Overview of DataFrame
df.head()
# Out:
#    Gender   Age  Height  Weight family_history FAVC  FCVC  NCP       CAEC  \
# 0  Female  21.0    1.62    64.0            yes   no   2.0  3.0  Sometimes
# 1  Female  21.0    1.52    56.0            yes   no   3.0  3.0  Sometimes
# 2    Male  23.0    1.80    77.0            yes   no   2.0  3.0  Sometimes
# 3    Male  27.0    1.80    87.0             no   no   3.0  3.0  Sometimes
# 4    Male  22.0    1.78    89.8             no   no   2.0  1.0  Sometimes
#
#   SMOKE  CH2O  SCC  FAF  TUE        CALC                 MTRANS  \
# 0    no   2.0   no  0.0  1.0          no  Public_Transportation
# 1   yes   3.0  yes  3.0  0.0   Sometimes  Public_Transportation
# 2    no   2.0   no  2.0  1.0  Frequently  Public_Transportation
# 3    no   2.0   no  2.0  0.0  Frequently                Walking
# 4    no   2.0   no  0.0  0.0   Sometimes  Public_Transportation
#
#                Obesity
# 0        Normal_Weight
# 1        Normal_Weight
# 2        Normal_Weight
# 3   Overweight_Level_I
# ...

# %%
print(df.shape)
# Out:
# (2111, 17)

# %% [markdown]
# overview of the dataset's size, the presence of missing values, and the types of data each column holds.

# %%
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2111 entries, 0 to 2110
# Data columns (total 17 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Gender          2111 non-null   object
#  1   Age             2111 non-null   float64
#  2   Height          2111 non-null   float64
#  3   Weight          2111 non-null   float64
#  4   family_history  2111 non-null   object
#  5   FAVC            2111 non-null   object
#  6   FCVC            2111 non-null   float64
#  7   NCP             2111 non-null   float64
#  8   CAEC            2111 non-null   object
#  9   SMOKE           2111 non-null   object
#  10  CH2O            2111 non-null   float64
#  11  SCC             2111 non-null   object
#  12  FAF             2111 non-null   float64
#  13  TUE             2111 non-null   float64
#  14  CALC            2111 non-null   object
#  15  MTRANS          2111 non-null   object
#  16  Obesity         2111 non-null   object
# ...

# %% [markdown]
#     The dataset contains 2111 entries and 17 columns, with both numerical (8 columns of type float64) and categorical (9 columns of type object) data. There are no missing values in any column

# %%
# describing the data
df.describe()
# Out:
#                Age       Height       Weight         FCVC          NCP  \
# count  2111.000000  2111.000000  2111.000000  2111.000000  2111.000000
# mean     24.312600     1.701677    86.586058     2.419043     2.685628
# std       6.345968     0.093305    26.191172     0.533927     0.778039
# min      14.000000     1.450000    39.000000     1.000000     1.000000
# 25%      19.947192     1.630000    65.473343     2.000000     2.658738
# 50%      22.777890     1.700499    83.000000     2.385502     3.000000
# 75%      26.000000     1.768464   107.430682     3.000000     3.000000
# max      61.000000     1.980000   173.000000     3.000000     4.000000
#
#               CH2O          FAF          TUE
# count  2111.000000  2111.000000  2111.000000
# mean      2.008011     1.010298     0.657866
# std       0.612953     0.850592     0.608927
# min       1.000000     0.000000     0.000000
# 25%       1.584812     0.124505     0.000000
# 50%       2.000000     1.000000     0.625350
# ...

# %% [markdown]
# The values mostly make sense and are realistic, though there are a couple of values that might seem a bit out of the ordinary. For example, a weight as low as 39 kg is on the extreme side which might indicate outliers, but it’s not impossible, some people may fall into that range. The height of 1.45 m is also on the shorter end, but it's definitely possible, especially for certain individuals. While these values are rare, they could still reflect real-world cases.

# %% [markdown]
# #
#
# <div style="text-align: center; border-top: 3px solid black; padding: 10px;">
#     <h2><strong>5. Data Cleaning</strong></h2>
# </div>

# %% [markdown]
# After using the info() and describe() functions for initial data inspection, we saw that there were no missing values. However, we will verify this further by explicitly checking for any missing values. Additionally, we will check for any duplicate rows in the dataset to ensure the data is clean.

# %%
# verify if theres no missing rows

no_missing_rows = df.isna().sum()

print(no_missing_rows)
# Out:
# Gender            0
# Age               0
# Height            0
# Weight            0
# family_history    0
# FAVC              0
# FCVC              0
# NCP               0
# CAEC              0
# SMOKE             0
# CH2O              0
# SCC               0
# FAF               0
# TUE               0
# CALC              0
# MTRANS            0
# Obesity           0
# dtype: int64

# %%
# Number of duplicate rows
duplicate_count_before = df.duplicated().sum()

# print duplicate count
print('Duplicate row count :',duplicate_count_before)

# remove duplicate rows
df = df.drop_duplicates()

# Number of duplicate rows after deleting
duplicate_count_after = df.duplicated().sum()

# print duplicate count
print('Duplicate row count after dropping duplicates:',duplicate_count_after)
# Out:
# Duplicate row count : 24
# Duplicate row count after dropping duplicates: 0

# %% [markdown]
#     Besides the dataset having duplicates, no missing values were found. After removing the duplicates, the dataset is now clean and free of any missing data and it is now ready for further analysis

# %% [markdown]
# #
#
# <div style="text-align: center; border-top: 3px solid black; padding: 10px;">
#     <h2><strong>6. Exploratoray Data Analysis</strong></h2>
# </div>

# %% [markdown]
# #
#
# <div style="text-align: center; padding: 10px;">
#     <h3><strong>6.1 Univariate Analysis</strong></h3>
# </div>

# %%
# Univariate analysis - Categorical features (display all categorical features with 5 per row)
categorical_columns = ['Gender', 'family_history', 'FAVC', 'CAEC', 'MTRANS', 'Obesity']

# Set up subplots: 1 row, 6 columns
fig, axes = plt.subplots(1, 6, figsize=(18, 5))  # Wide figure to fit all plots

glossy_style = {'alpha': 0.8, 'edgecolor': 'black'} 

for i, col in enumerate(categorical_columns):
    sns.countplot(x=df[col], ax=axes[i], color='skyblue', **glossy_style)
    axes[i].set_title(f'{col}')
    axes[i].tick_params(axis='x', rotation=90)

plt.tight_layout(pad=1.5)  # Adjust padding for better spacing
plt.show()

# %% [markdown]
# - __Gender:__ The dataset seems to have a balanced distribution between Male and Female respondents.
#
# - __Family History:__ A significant majority of individuals have a family history of obesity, which could be an important predictive factor.
#
# - __Frequent Consumption of High-Calorie Food (FAVC):__ Most individuals in the dataset consume high-calorie food frequently, which aligns with obesity risk factors.
#
# - __Consumption of Food Between Meals (CAEC):__ The majority of people in the dataset consume food "Sometimes," with smaller groups reporting frequent or always snacking.
#
# - __Mode of Transportation (MTRANS):__ Most individuals use public transportation or walk, with fewer using motorbikes, automobiles, or bicycles.
#
# - __Obesity:__ The distribution of obesity levels appears to be relatively balanced, though some categories have slightly higher counts,this is good as this featur will be later used as our target feature

# %%
# Univariate analysis - Numerical features (display all numerical features with 4 per row)
numerical_columns = ['Age', 'Height', 'Weight', 'FCVC', 'NCP', 'CH2O', 'FAF', 'TUE']
fig, axes = plt.subplots(2, 4, figsize=(16, 8))  # 2 rows, 4 columns

for i, col in enumerate(numerical_columns):
    ax = axes[i // 4, i % 4]  # Calculate row and column
    sns.histplot(df[col], kde=True, ax=ax,color='skyblue')
    ax.set_title(f'Distribution of {col}')

plt.tight_layout(pad=1.0)  # Adjust padding between plots
plt.show()

# %% [markdown]
# -  __Age:__ Presents a right-skewed plot meaning most individuals are relatively young,most being less than 30 years
# - __NCP (Number of Main Meals per Day):__ Strong peaks at 3 meals per day, likely the standard.
# - __FAF (Physical Activity Frequency per Week):__ Right-skewed, meaning many individuals have low physical activity.
# - __FCVC (Frequency of Vegetable Consumption):__ Suprisingly Many individuals have high vegetable consumption.

# %% [markdown]
# #
#
# <div style="text-align: center; padding: 10px;">
#     <h3><strong>6.2. Multivariate Analysis</strong></h3>
# </div>

# %%
# Calculate correlation matrix for numerical columns
corr_matrix = df[numerical_columns].corr()


plt.figure(figsize=(8, 6))  # Adjust figure size

# Create and display the heatmap with annotations and color map
sns.heatmap(corr_matrix, annot=True, cmap='coolwarm', fmt=".2f", linewidths=0.5)
plt.title("Correlation Matrix Heatmap") 
plt.show()

# %% [markdown]
# - __Height and Weight:__ A moderate positive correlation (0.46) is expected. Taller people tend to weigh more.
# - __Age and TUE (Time Using Electronic devices):__ A weak negative correlation (-0.30) might suggests that older individuals tend to spend less time using electronic devices.
#
# While many of the numerical features exhibit weak correlations with each other, possibly due to non-linear relationships or their inherent independence, we will explore potential patterns by analyzing them alongside the categorical features.

# %%
# Set figure size
fig, axes = plt.subplots(1, 3, figsize=(18, 7))

# Define colors
colors = ['skyblue', 'dodgerblue', 'deepskyblue']

glossy_style = {'alpha': 0.8, 'edgecolor': 'black'}  # Glossy effect

# Plot 1: Physical Activity vs Obesity Level
sns.barplot(ax=axes[0], x='Obesity', y='FAF', data=df, color=colors[0], **glossy_style)
axes[0].set_title('Physical Activity vs Obesity Class')
axes[0].tick_params(axis='x', rotation=90)

# Plot 2: Means of Transportation vs Weight
sns.barplot(ax=axes[1], x='MTRANS', y='Weight', data=df, color=colors[1], **glossy_style)
axes[1].set_title('Means of Transportation vs Weight')
axes[1].tick_params(axis='x', rotation=90)

# Plot 3: Calorie Consumption vs Weight
sns.barplot(ax=axes[2], x='FAVC', y='Weight', data=df, color=colors[2], **glossy_style)
axes[2].set_title('Calorie Consumption vs Weight')
axes[2].tick_params(axis='x', rotation=90)

# Adjust layout for better spacing
plt.tight_layout()

# Display the plots
plt.show()

# %% [markdown]
# ##### **Physical Activity vs Obesity Level**
# - Normal weight individuals tend to have the highest **physical activity frequency (FAF)**.
# - Obesity Type III individuals show the lowest **Physical Activity**, indicating a strong inverse relationship between physical activity and obesity.
# - Overweight and Obesity Type I & II groups have moderate **Physical Activity**, suggesting a declining trend as weight increases.
#
# ##### **Means of Transportation vs Weight**
# - **Public transportation users** appear to have a **higher weight on average** compared to those who walk.
# - **Walking and biking** are associated with **lower weights**, suggesting that active transportation helps manage weight.
# - **Automobile and motorbike users** fall somewhere in the middle, but still tend to have **higher weights than walkers**.
#
# ##### **Calorie Consumption vs Weight (FAVC - Frequent Consumption of High-Calorie Foods)**
# - Individuals who **frequently consume high-calorie foods ("yes") have a significantly higher weight** than those who do not.
# - This clearly shows the impact of **excessive calorie intake on weight gain**, aligning with obesity risk factors.
#
# ✅ **Physical activity inversely correlates with obesity levels.**
# ✅ **Active transport methods like walking and biking are linked to lower weight.**
# ✅ **Frequent high-calorie food consumption contributes to weight gain.**

# %%
# Define height categories based on observed values
def categorize_height(height):
    if height < 1.60:
        return 'Short'
    elif 1.60 <= height < 1.75:
        return 'Medium'
    else:
        return 'Tall'

# Apply the function to create a new column
df['Height_Category'] = df['Height'].apply(categorize_height)

# %%
# Define age categories
def categorize_age(age):
    if age < 25:
        return 'Young'
    elif 25 <= age < 45:
        return 'Adult'
    elif 45 <= age <= 60:
        return 'Mid-age'
    else:
        return 'Old'

# Apply the function to create a new column
df['Age_Category'] = df['Age'].apply(categorize_age)

# %%
# Calculate the average weight by Age_Category and Height_Category
avg_weight_age = df.groupby('Age_Category')['Weight'].mean()
avg_weight_height = df.groupby('Height_Category')['Weight'].mean()

# Create a color palette using blues
colors_age = sns.light_palette("royalblue", n_colors=len(avg_weight_age), reverse=True)
colors_height = sns.light_palette("deepskyblue", n_colors=len(avg_weight_height), reverse=True)

# Create the figure and axes for two pie charts
fig, axes = plt.subplots(1, 2, figsize=(12, 8))

# Plot Average Weight by Age Category on the first axis
axes[0].pie(avg_weight_age, labels=avg_weight_age.index, autopct='%1.0f%%', startangle=90, colors=colors_age)
axes[0].set_title('Average Weight Distribution by Age Category', y=0.8)
axes[0].axis('equal')  # Equal aspect ratio ensures the pie chart is drawn as a circle

# Plot Average Weight by Height Category on the second axis
axes[1].pie(avg_weight_height, labels=avg_weight_height.index, autopct='%1.0f%%', startangle=90, colors=colors_height)
axes[1].set_title('Average Weight Distribution by Height Category', y=0.8)
axes[1].axis('equal')

# Adjust layout to prevent overlap
plt.subplots_adjust(wspace=1)

# Show the plot
plt.show()

# %% [markdown]
# #### __Average Weight Distribution by Age Category__
# - Most age categories show similar average weights, except for the older age group, which stands out with a significantly lower average weight.
# - The Old category has the lowest average weight, which could be due to various factors such as aging, changes in metabolism, and health conditions
#
# #### __Average Weight by Height Category__
# - Taller people generally have larger frames and more muscle mass, which contributes to higher body weight.
# - Shorter individuals might have smaller frames and less muscle mass on average, leading to lower weight.

# %%
df.drop(columns=['Age_Category','Height_Category'], axis=1,inplace=True)

# %% [markdown]
#     The 'Age_Category' and 'Height_Category' columns are dropped to restore the DataFrame to its original state.

# %% [markdown]
# #
#
# <div style="text-align: center; border-top: 3px solid black; padding: 10px;">
#     <h2><strong>7.Data Preprocessing</strong></h2>
# </div>

# %% [markdown]
# #
#
# <div style="text-align: center; padding: 10px;">
#     <h3><strong>7.1. Feature Engineering</strong></h3>
# </div>

# %% [markdown]
# The target variable will be encoded using `LabelEncoder`, while features will be encoded based on the number of classes. Features with only two classes will be encoded using `LabelEncoder`, and features with multiple classes will be encoded using `One-Hot Encoding`. This approach is used because `LabelEncoder` is more suitable for binary classification, while `One-Hot Encoding` avoids creating `ordinal` relationships for multi-class features.

# %%
# Initialize LabelEncoder
label_encoder = LabelEncoder()

# Label encode the 'Obesity' 
df['Obesity'] = label_encoder.fit_transform(df['Obesity'])

# Get the mapping of labels to numbers
label_to_number = dict(zip(label_encoder.classes_, range(len(label_encoder.classes_))))

print("Label to Number Mapping:", label_to_number)


# Label encoding for binary columns
df['Gender'] = label_encoder.fit_transform(df['Gender'])
df['family_history'] = label_encoder.fit_transform(df['family_history'])
df['SMOKE'] = label_encoder.fit_transform(df['SMOKE'])
df['FAVC'] = label_encoder.fit_transform(df['FAVC'])
df['SCC'] = label_encoder.fit_transform(df['SCC'])

# One-hot encoding for multi-class columns, returning 0/1 instead of True/False
df_encoded = pd.get_dummies(df, columns=['MTRANS', 'CALC', 'CAEC'], drop_first=True)

# Convert only the one-hot encoded columns to integers
df_encoded[df_encoded.columns[df_encoded.columns.str.startswith(('MTRANS', 'CALC', 'CAEC'))]] = df_encoded[df_encoded.columns[df_encoded.columns.str.startswith(('MTRANS', 'CALC', 'CAEC'))]].astype(int)
# Out:
# Label to Number Mapping: {'Insufficient_Weight': 0, 'Normal_Weight': 1, 'Obesity_Type_I': 2, 'Obesity_Type_II': 3, 'Obesity_Type_III': 4, 'Overweight_Level_I': 5, 'Overweight_Level_II': 6}

# %%
# Reverse the dictionary to map numbers back to labels
number_to_label = {v: k for k, v in label_to_number.items()}

# Use number_to_label to get target names
target_names = [number_to_label[i] for i in range(len(label_to_number))]

# %%
df_encoded.shape
# Out:
# (2087, 24)

# %%
df_encoded.head()
# Out:
#    Gender   Age  Height  Weight  family_history  FAVC  FCVC  NCP  SMOKE  CH2O  \
# 0       0  21.0    1.62    64.0               1     0   2.0  3.0      0   2.0
# 1       0  21.0    1.52    56.0               1     0   3.0  3.0      1   3.0
# 2       1  23.0    1.80    77.0               1     0   2.0  3.0      0   2.0
# 3       1  27.0    1.80    87.0               0     0   3.0  3.0      0   2.0
# 4       1  22.0    1.78    89.8               0     0   2.0  1.0      0   2.0
#
#    ...  MTRANS_Bike  MTRANS_Motorbike  MTRANS_Public_Transportation  \
# 0  ...            0                 0                             1
# 1  ...            0                 0                             1
# 2  ...            0                 0                             1
# 3  ...            0                 0                             0
# 4  ...            0                 0                             1
#
#    MTRANS_Walking  CALC_Frequently  CALC_Sometimes  CALC_no  CAEC_Frequently  \
# ...

# %% [markdown]
#     The dimensionality of the dataset has increased from 17 to 24 columns, with 7 additional columns added.

# %%
# Initialize features(X) and target variable(y)
X = df_encoded.drop('Obesity',axis=1) # Features
y = df_encoded['Obesity'] # Target Variable

# Split data in train and test set,with 75% train and 25% test
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=42)

# %% [markdown]
# Only continuous features will be scaled, while categorical features (One-Hot encoded) will be left as is because scaling is typically applied to numerical data to normalize the range and distribution, ensuring that continuous variables have a mean of 0 and standard deviation of 1. Categorical variables, after One-Hot encoding, are already in binary form and do not require scaling, as they represent discrete categories rather than continuous quantities

# %%
# Initialize Scaler
scaler = StandardScaler()

# features to be scale
continous_features = ['Age','Height','Weight','FCVC','NCP','CH2O','FAF','TUE']

# Step 1: Scale only the continuous features in X_train
X_train_scaled = X_train.copy()  # Copy to keep original intact
X_train_scaled[continous_features] = scaler.fit_transform(X_train[continous_features])

# Step 2: Scale the continuous features in X_test using the same scaler
X_test_scaled = X_test.copy()  # Copy to keep original intact
X_test_scaled[continous_features] = scaler.transform(X_test[continous_features])

# %% [markdown]
# After splitting the data into subsets, a bar graph is plotted to observe the class distribution in each set.

# %%
# Glossy style settings
glossy_style = {'alpha': 0.8, 'edgecolor': 'black'}  # Glossy effect

# Create a subplot with two axes
fig, axes = plt.subplots(1, 2, figsize=(8, 4))

# Define colors
colors = ['skyblue', 'dodgerblue', 'deepskyblue']

# Countplot for y_train
sns.countplot(x=y_train, ax=axes[0], linewidth=1.5, color=colors[2], **glossy_style)
axes[0].set_title('Training Set')
axes[0].set_xlabel('Obesity Category')
axes[0].set_ylabel('Count')

# Countplot for y_test
sns.countplot(x=y_test, ax=axes[1], linewidth=1.5, color=colors[1],**glossy_style)
axes[1].set_title('Testing Set')
axes[1].set_xlabel('Obesity Category')
axes[1].set_ylabel('Count')

# Apply a glossy style
plt.style.use('seaborn-poster')
plt.tight_layout()
plt.show()

# %% [markdown]
# The distribution of obesity categories in both the training and testing sets is relatively balanced, with some variations. In the training set, category 2 has the highest count, while category 1 appears less frequent. A similar pattern is observed in the testing set, where category 6 is notably underrepresented. Despite these differences, the overall distribution should still support effective model training

# %% [markdown]
# #
#
# <div style="text-align: center; border-top: 3px solid black; padding: 10px;">
#     <h2><strong>8. Model Development</strong></h2>
# </div>

# %% [markdown]
# #
#
# <div style="text-align: center; padding: 10px;">
#     <h3><strong>8.1. Logistic Regression</strong></h3>
# </div>

# %% [markdown]
# A __logistic regression__ model will be implemented to predict the multiclass outcomes. __Logistic regression__ is particularly effective at handling __binary__ and __multiclass__ classification tasks due to its simplicity and interpretability.

# %%
# Define the Logistic Regression model
lr_model = LogisticRegression(random_state=42)

# %%
# Define the hyperparameter grid for tuning
param_grid = {
    'C': [0.1, 1, 10],  
    'solver': ['liblinear', 'lbfgs'],  
    'penalty': ['l2'],  
    'max_iter': [100, 500, 1000, 1500], 
}

# %%
# Initialize GridSearchCV for hyperparameter tuning
grid_search = GridSearchCV(
    estimator=lr_model,      
    param_grid=param_grid,  
    cv=5,                   
    n_jobs=-1,              
    scoring='accuracy'     
)

# %%
# Train the model using grid search
grid_search.fit(X_train_scaled, y_train)
# Out:
# GridSearchCV(cv=5, estimator=LogisticRegression(random_state=42), n_jobs=-1,
#              param_grid={'C': [0.1, 1, 10], 'max_iter': [100, 500, 1000, 1500],
#                          'penalty': ['l2'], 'solver': ['liblinear', 'lbfgs']},
#              scoring='accuracy')

# %%
# Display the best hyperparameters and corresponding cross-validation accuracy
print("Best Hyperparameters:", grid_search.best_params_)
# Out:
# Best Hyperparameters: {'C': 10, 'max_iter': 500, 'penalty': 'l2', 'solver': 'lbfgs'}

# %%
# Use the best model to make predictions on the test set
best_model = grid_search.best_estimator_
y_pred_lr = best_model.predict(X_test_scaled)
y_pred_prob = best_model.predict_proba(X_test_scaled)
lr_report = classification_report(y_test, y_pred_lr, target_names=target_names)

# Train and Test accuracy
lr_cv_accuracy = grid_search.best_score_
lr_train_accuracy = best_model.score(X_train_scaled, y_train)
lr_test_accuracy = best_model.score(X_test_scaled, y_test)

# Print metrics scores
print(f"Best Validation Accuracy (CV Score): {lr_cv_accuracy:.2f}")
print(f"Train Accuracy: {lr_train_accuracy:.2}")
print(f"Test Accuracy: {lr_test_accuracy:.2f}")
print(f"Log Loss Error: {log_loss(y_test,y_pred_prob)}")
print("_"*60)

print("Classification Report:\n", lr_report)
# Out:
# Best Validation Accuracy (CV Score): 0.94
# Train Accuracy: 0.97
# Test Accuracy: 0.93
# Log Loss Error: 0.21976725106007095
# ____________________________________________________________
# Classification Report:
#                       precision    recall  f1-score   support
#
# Insufficient_Weight       0.95      0.97      0.96        74
#       Normal_Weight       0.94      0.88      0.91        76
#      Obesity_Type_I       0.96      0.94      0.95        85
#     Obesity_Type_II       0.98      1.00      0.99        82
#    Obesity_Type_III       1.00      1.00      1.00        77
#  Overweight_Level_I       0.86      0.83      0.84        71
# Overweight_Level_II       0.79      0.86      0.82        57
#
#            accuracy                           0.93       522
#           macro avg       0.93      0.93      0.93       522
#        weighted avg       0.93      0.93      0.93       522

# %% [markdown]
# The model is performing well, with a training accuracy of 97% and a test accuracy of __93%__, indicating strong classification capabilities. The cross-validation score of __94%__ further supports its consistency across different subsets of data.
#
# However, there is a slight overfitting issue, as the training accuracy is notably higher than the test accuracy. While the difference isn’t extreme, it suggests that the model is learning some patterns too specifically from the training data, leading to slightly reduced generalization on new data.
#
# Since both the macro and weighted F1-scores are __93%__, the model is consistently performing well across all classes, without favoring one category over another.

# %% [markdown]
# #
#
# <div style="text-align: center; padding: 10px;">
#     <h3><strong>8.2. Support Vector Machine</strong></h3>
# </div>

# %% [markdown]
# Next, a Support Vector Machine (SVM) will be used to determine if it can outperform the previous logistic regression model. SVM is a strong contender because it excels at finding optimal decision boundaries, handles high-dimensional data effectively, and can capture complex patterns using kernel tricks.

# %%
# Define svm model
svm_model = SVC(probability=True)

# %%
# Define the Hyperparameter Grid
param_grid = {
    'C': [0.1, 1, 4],     
    'kernel': ['linear', 'rbf', 'poly'],  
    'gamma': ['scale', 'auto', 0.01, 0.1]  
}

# %%
# Define grid_search
grid_search_svm = GridSearchCV(
    svm_model, param_grid, 
    cv=5, scoring='accuracy', 
    verbose=1, 
    n_jobs=-1
    )

# %%
grid_search_svm.fit(X_train_scaled, y_train)
# Out:
# Fitting 5 folds for each of 36 candidates, totalling 180 fits
# GridSearchCV(cv=5, estimator=SVC(probability=True), n_jobs=-1,
#              param_grid={'C': [0.1, 1, 4],
#                          'gamma': ['scale', 'auto', 0.01, 0.1],
#                          'kernel': ['linear', 'rbf', 'poly']},
#              scoring='accuracy', verbose=1)

# %%
# Display the best hyperparameters and corresponding cross-validation accuracy
print("Best Hyperparameters:", grid_search_svm.best_params_)
# Out:
# Best Hyperparameters: {'C': 4, 'gamma': 'scale', 'kernel': 'linear'}

# %%
# Use the best model to make predictions on the test set
best_svm_model = grid_search_svm.best_estimator_
y_pred_svm = best_svm_model.predict(X_test_scaled)
y_pred_prob_svm = best_svm_model.predict_proba(X_test_scaled)

# Train and Test accuracy
svm_cv_accuracy = grid_search_svm.best_score_
svm_train_accuracy = best_svm_model.score(X_train_scaled, y_train)
svm_test_accuracy = best_svm_model.score(X_test_scaled, y_test)
svm_report = classification_report(y_test, y_pred_svm, target_names=target_names)

# Print metrics scores
print(f"Best Validation Accuracy (CV Score): {svm_cv_accuracy:.2f}")
print(f"Train Accuracy: {svm_train_accuracy:.2f}")
print(f"Test Accuracy: {svm_test_accuracy:.2f}")
print(f"Log Loss Error: {log_loss(y_test,y_pred_prob_svm)}")
print("_"*60)

print("Classification Report:\n", svm_report)
# Out:
# Best Validation Accuracy (CV Score): 0.96
# Train Accuracy: 0.98
# Test Accuracy: 0.97
# Log Loss Error: 0.11643643763930453
# ____________________________________________________________
# Classification Report:
#                       precision    recall  f1-score   support
#
# Insufficient_Weight       0.99      0.97      0.98        74
#       Normal_Weight       0.96      0.97      0.97        76
#      Obesity_Type_I       0.99      0.95      0.97        85
#     Obesity_Type_II       0.98      1.00      0.99        82
#    Obesity_Type_III       1.00      1.00      1.00        77
#  Overweight_Level_I       0.94      0.92      0.93        71
# Overweight_Level_II       0.88      0.93      0.91        57
#
#            accuracy                           0.97       522
#           macro avg       0.96      0.96      0.96       522
#        weighted avg       0.97      0.97      0.97       522

# %% [markdown]
# - The model demonstrates high overall accuracy across training __98%__, validation __96%__, and test __97%__ sets, indicating strong generalization.
# - The low log loss of 0.116 suggests that the model is making confident predictions with minimal uncertainty.
# - The weighted average F1-score of __97%__ takes into account class imbalances, giving more weight to the classes with larger support. This indicates the model is particularly strong in handling classes with more instances, while still maintaining good performance on smaller classes

# %% [markdown]
# #
#
# <div style="text-align: center; border-top: 3px solid black; padding: 10px;">
#     <h2><strong>9. Model Evaluation</strong></h2>
# </div>

# %% [markdown]
# This evaluation aims to determine which model performs better between logistic regression (LR) and support vector machine (SVM), comparing their strengths and how each tackles the classification task.

# %%
# Set the seaborn style 
sns.set(style="whitegrid")

# transform the evaluation data to a dictionary
data = {
    'Model': ['Logistic Regression', 'Support Vector Machine'],
    'Train Accuracy': [lr_train_accuracy, svm_train_accuracy],
    'Test Accuracy': [lr_test_accuracy, svm_test_accuracy],
    'CV Accuracy': [lr_cv_accuracy, svm_cv_accuracy]
}

# Convert the dictionary into a DataFrame
df_evaluation = pd.DataFrame(data)

# Reshape the DataFrame for plotting
df_melted = df_evaluation.melt(id_vars='Model', var_name='Accuracy Type', value_name='Accuracy')

# Define the custom color 
custom_colors = ['skyblue', 'dodgerblue', 'deepskyblue']

# Create the horizontal side-by-side bar plot with custom colors
plt.figure(figsize=(8, 4))
ax = sns.barplot(data=df_melted, y='Model', x='Accuracy', hue='Accuracy Type', dodge=True, orient='h', palette=custom_colors)

# Add labels and title
plt.title('Comparison of Model Accuracies')
plt.xlabel('Accuracy')
plt.ylabel('Model')

# Display the accuracy values only outside the bars
for p in ax.patches:
    width = p.get_width()
    y_position = p.get_y() + p.get_height() / 2
    # Only display values outside the bars
    if width > 0:
        ax.text(width + 0.01, y_position, f'{width:.2f}', ha='left', va='center', fontsize=12)

# Move the legend outside the plot
plt.legend(title='Accuracy Type', bbox_to_anchor=(1.05, 1), loc='upper left')

# Display the plot
plt.show()

# %% [markdown]
# The Support Vector Machine (SVM) is the better model because it has a higher test accuracy (0.97 vs. 0.93) and cross-validation accuracy (0.96 vs. 0.94) compared to Logistic Regression. Additionally, the small gap between its training and test accuracy suggests that SVM does not overfit, making it a more reliable choice for generalizing to unseen data.

# %%
# Generate classification reports as dictionaries for both models
lr_report_dict = classification_report(y_test, y_pred_lr, target_names=target_names, output_dict=True)
svm_report_dict = classification_report(y_test, y_pred_svm, target_names=target_names, output_dict=True)

# Extract the weighted average recall for each model
svm_weighted_recall = svm_report_dict['weighted avg']['recall']  # SVM model's recall, weighted by class support
lr_weighted_recall = lr_report_dict['weighted avg']['recall']  # Logistic Regression model's weighted recall

# %%
# Data
models = ["Logistic Regression", "Support Vector Machine"]
weighted_recalls = [lr_weighted_recall, svm_weighted_recall]

# Style and plot
sns.set_style("darkgrid")
plt.figure(figsize=(6, 4))
ax = sns.barplot(x=models, y=weighted_recalls, palette="Blues_r")

# Add values
for i, recall in enumerate(weighted_recalls):
    ax.text(i, recall + 0.02, f"{recall:.2f}", ha='center', fontsize=10, color="black")

# Formatting
plt.title("Weighted Recall Comparison", fontsize=14)
plt.grid(False)
plt.show()

# %% [markdown]
# - The Support Vector Machine (SVM) model has a weighted recall of 0.97, while Logistic Regression has 0.93,This means SVM correctly identifies a higher proportion of actual positive cases across all classes.
#
# - Since recall measures how well the model captures positive cases, SVM is less likely to miss important cases compared to Logistic Regression.
# - This is especially important in scenarios where false negatives are costly, such as medical diagnoses or fraud detection.

# %%
# Function to plot confusion matrix
def confusion_matrix_visualizer(conf_matrix1, conf_matrix2, model_name1, model_name2):
    """
    Plots two confusion matrices side by side for two models.

    Parameters:
    - conf_matrix1: The first confusion matrix to be visualized.
    - conf_matrix2: The second confusion matrix to be visualized.
    - model_name1: The name of the first model (e.g., 'Logistic Regression').
    - model_name2: The name of the second model (e.g., 'Random Forest').
    """
    
    # Assuming number_to_label is predefined (the labels for your classes)
    labels = number_to_label
    class_labels = [labels[i] for i in range(7)]  # Adjust if the number of classes is different

    # Create a figure with two subplots (side by side)
    fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(12, 6))  # 1 row, 2 columns

    # Create the ConfusionMatrixDisplay for both models
    disp1 = ConfusionMatrixDisplay(confusion_matrix=conf_matrix1, display_labels=class_labels)
    disp2 = ConfusionMatrixDisplay(confusion_matrix=conf_matrix2, display_labels=class_labels)

    # Plot the confusion matrices
    disp1.plot(cmap="Blues", values_format="d", ax=ax1, colorbar=False)
    disp2.plot(cmap="Blues", values_format="d", ax=ax2, colorbar=False)

    # Remove the grid and set the titles
    ax1.grid(False)
    ax2.grid(False)
    ax1.set_xticklabels(ax1.get_xticklabels(), rotation=90)
    ax2.set_xticklabels(ax2.get_xticklabels(), rotation=90)
    ax1.set_title(f"{model_name1} Confusion Matrix")
    ax2.set_title(f"{model_name2} Confusion Matrix")
    
    # Adjust layout to minimize space
    plt.tight_layout()

    # Show the plot
    plt.show()

# %%
# Define the svm and lr confusion matrix
svm_conf_matrix = confusion_matrix(y_test,y_pred_svm)
lr_conf_matrix = confusion_matrix(y_test,y_pred)

# %%
# Execute function
confusion_matrix_visualizer(lr_conf_matrix,svm_conf_matrix,lr_model,svm_model)

# %% [markdown]
# Logistic Regression struggles with distinguishing Overweight Level 1 and Overweight Level 2, as well as Normal Weight and Overweight Level 1, leading to frequent misclassifications. While the SVM model also faces similar challenges, it reduces these errors to half of what Logistic Regression does. This suggests that SVM is better at capturing subtle differences between closely related weight categories, making it the stronger choice for this task.
#
#
# __*Support Vector Machine (SVM) consistently outperforms logistic regression across all evaluated metrics, establishing itself as the superior model in terms of both performance and reliability*__
